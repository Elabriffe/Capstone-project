# %% [markdown]
# # 1. Introduction

# %% [markdown]
#  ## 1.1 Background

# %% [markdown]
# Paris is known for its culinary cuisine and culture. In addition, Paris is one of the most attractive cities in France where it is interesting to open a business. Moreover it is one of the most multicultural cities in France and therefore an interesting place to open a new business. Moreover we are one of the largest business centers in France, but also many cultural sites are present there attracting many tourists. So many advantages that can be interesting to open a restaurant.

# %% [markdown]
# ## 1.2. Problem description:

# %% [markdown]
# Paris is a city of many cultures. In addition of many people from different backgrounds have settled in Paris: Africans, South Americans, Asians, Eastern Europeans and they have all brought with them their particular culture in the Parisian diversity. Thanks to this unique mix of cultures in Paris, you can find an infinite number of small ethnic restaurants that offer an alternative to the classic Parisian restaurants, the "brasseries".
#
# In Paris, as in the main cities of France, you will find all kinds of kitchens from every corner of the globe. And honestly, it is almost impossible to list all the countries represented in the Parisian gastronomic landscape here.
#
# However, due to colonial ties or mass immigration, some types of cuisine are more common and therefore easier to find. The list below therefore presents some of the most represented and influential countries in Paris gastronomy.
#
# **Vietnam**
#
# Vietnam was a French colony from 1887 to 1954 and, as a result, a large Vietnamese community resided in France. During the colonial period, both cultures strongly influenced their respective cuisines, as evidenced by dishes such as the Vietnamese "banh mi", a sandwich that uses a rice flour version of the famous French baguette. You can also find distinctly Vietnamese dishes, such as the "pho" (pronounced - fire -) which originated from the French "pot au feu".
#
# **Senegal**
#
# Like Vietnam, Senegal is another former colony whose culture and cuisine has strongly influenced France. Many Senegalese immigrants brought refined dishes such as "Thiebou Yap", (cooked beef or lamb, vegetables, seasonings, rice) and "Yassa", (chicken marinated in spices and simmered in a pan with mustard, onion and lemon juice, and served with rice).
#
# **Lebanon**
#
# Although France occupied Lebanon from World War I until the late 1950s, many Lebanese immigrated in 1975 because of the civil war, thus enlarging the small community that already existed in the country. These immigrants brought with them classic staple foods such as hummus and pita bread, as well as "baba ganoush", a dish made from roasted eggplant. Today, many Lebanese restaurants, from stalls to gourmet restaurants, dot the streets of Paris and beyond.
#
# **Morocco**
#
# People of Moroccan origin form one of the largest communities of foreign origin in France due to mass immigration after the colonial period. Like many other North African countries, Moroccan cuisine combines elements of diverse origins: Arabic, Mediterranean, Berber and other neighboring cultures. The classic Moroccan "tajines" cook meat or vegetables in a terracotta dish. And the "Fassi B'stilla" (or pastilla) is a kind of pie made of ingredients ranging from pigeon to chicken with cinnamon.
#
# **Japan**
#
# Japanese expatriates have frequently visited France since the 1870s to study and appreciate its culture. Today, many people of Japanese origin live there and many Japanese expatriates reside there for long periods of time. These long-established Japanese communities have introduced classic establishments such as sushi and noodle bars into the French culinary landscape. Many renowned chefs, such as Sadaharu Aoki, mix French and Japanese culinary traditions and pastries in an amazing way.
#
# And to face this diversity, it's therefore important to be strategically placed in Paris to attract people. That's why for this problem. We would need to study different important point to decide about the location of the restaurant in Paris.
#
# * Which kind of population in the different neigberhoods. (Depending on which kind of restaurant we want to open, the location may vary)
#
# * Is there any centers near to this place and maybe there would be more floating people.
#
# * What's the influence during the day in the different neighberhood
#
# * Are thre any work center close to our place so that people could eat at noon
#
# * The peers, competitors in the different place
#
# * Shops and market around our place, Can a short circuit be used ? Can we find a way to have fresh product every day

# %% [markdown]
# ## 2. Data for the project

# %% [markdown]
# ### Dataset 1 : Population density
#
#
# A dataset with the population density by neighberhood on Paris so that we could see where are the best neighberhood with lots of population.
#
# The following dataset could help us to achieve that :
#
# https://www.data.gouv.fr/fr/datasets/r/e88c6fda-1d09-42a0-a069-606d3259114e
#
# In this set of data we wll find different info as :
#
# * num_arr: number of borough;
# * nom_dept: name of department;
# * nom_region: name of region;
# * population: number of population by 1000;
#
# ### Dataset 2 : Market, Food supplier in paris
#
# website : https://opendata.paris.fr
#
# From this website, we can download the data concerning the Paris local markets (Marchés découverts).
#
# <img src="https://github.com/Elabriffe/Capstone-project/blob/main/Capture%20d%E2%80%99e%CC%81cran%202021-01-18%20a%CC%80%2020.16.41.png?raw=true"/>
#
# This dataset contains the following information :
#
# * Market name and description
# * Product in which the market specialises — such as Food, Bio Food, Art, Flower etc..
# * Arrondissement — Paris is divided into zones called Arrondissement. So this field indicates in which zone the market is located in.
# * Monday to Sunday — A 1 in this column indicates that the market is open on that day
# * Latitude, Longitude — which indicates the geo-location of the market. This is more precise than Arrondissement for the location information
#
# Indeed it's important for restaurant to have fresh dishes and be close to market to be the most efficient possible.
# We could have also more market by using the Foursquare API which could provide some other market to have more info about the market in paris.

# %% [markdown]
# <img src="https://github.com/Elabriffe/Capstone-project/blob/main/Capture%20d%E2%80%99e%CC%81cran%202021-01-19%20a%CC%80%2020.54.43.png?raw=true"/>

# %% [markdown]
# ### Dataset 3 : Peers, competitors in Paris
#
# We can use different dataset for this part as many of them are available on different websites. A complete one is available on kaggle :
#
# https://www.kaggle.com/svrcek/paris-restaurants
#
# <img src="https://github.com/Elabriffe/Capstone-project/blob/main/Capture%20d%E2%80%99e%CC%81cran%202021-01-19%20a%CC%80%2021.14.15.png?raw=true"/>
#
# In this dataset, we have the following elements :
#
# * postal code (code)
# * Nom restaurant (restaurant name)
# * adresse (address)
# * ville (city)
# * longitude and latitude
#
# Other data could be used and could be retrieve from the Foursquare API.

# %% [markdown]
# <img src="https://github.com/Elabriffe/Capstone-project/blob/main/Capture%20d%E2%80%99e%CC%81cran%202021-01-19%20a%CC%80%2021.18.13.png?raw=true"/>

# %% [markdown]
# ## 3. Methodology
#
# As a reminder, the objective of this project is to find the place the most suitable to open a restaurant in Paris.
# So we'll use the datasets presented before to achieve that.
#
# * 1st one will help us to define place where we can find the most important density.
# * 2nd one to find the place where are the place with market to get fresh dishes
# * 3rd one to find the place without peers so that we have less competitors.
#
# Finally we could use as seen previously the k-means method to find the right segmentation which correspond to our different criteria.

# %%
#!pip install wordcloud
#%% capture
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


#from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

import folium # plotting library

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
##############################neighborhood dataset#####################################
comm=pd.read_json(r'/Users/edouardlabriffe/Desktop/correspondances-code-insee-code-postal (1).json')["fields"]#[0]['code_comm']
name_set=["postal_code","region","statut","population","nom_dept","longitude","latitude"]
neighborhood=pd.DataFrame(columns=name_set)
for i in range(len(comm)):
     neighborhood = neighborhood.append({'postal_code': comm[i]["postal_code"],
                                          'region': comm[i]["nom_region"],
                                         'statut' : comm[i]["statut"],
                                          'population' : comm[i]["population"],
                                          'nom_dept' : comm[i]["nom_dept"],
                                          'latitude': comm[i]["geo_point_2d"][0],
                                          'longitude': comm[i]["geo_point_2d"][1]}, ignore_index=True)

neighborhood=neighborhood[neighborhood["nom_dept"]=="PARIS"].reset_index()
neighborhood.drop(columns=["index"],inplace=True)
neighborhood
# Out:
#    postal_code         region            statut  population nom_dept  \
# 0        75009  ILE-DE-FRANCE  Chef-lieu canton        60.3    PARIS
# 1        75002  ILE-DE-FRANCE  Chef-lieu canton        22.4    PARIS
# 2        75011  ILE-DE-FRANCE  Chef-lieu canton       152.7    PARIS
# 3        75003  ILE-DE-FRANCE  Chef-lieu canton        35.7    PARIS
# 4        75006  ILE-DE-FRANCE  Chef-lieu canton        43.1    PARIS
# 5        75004  ILE-DE-FRANCE  Chef-lieu canton        28.2    PARIS
# 6        75001  ILE-DE-FRANCE   Capitale d'état        17.6    PARIS
# 7        75017  ILE-DE-FRANCE  Chef-lieu canton       168.5    PARIS
# 8        75008  ILE-DE-FRANCE  Chef-lieu canton        40.3    PARIS
# 9        75013  ILE-DE-FRANCE  Chef-lieu canton       182.0    PARIS
# 10       75012  ILE-DE-FRANCE  Chef-lieu canton       142.9    PARIS
# 11       75005  ILE-DE-FRANCE  Chef-lieu canton        61.5    PARIS
# 12       75019  ILE-DE-FRANCE  Chef-lieu canton       184.8    PARIS
# 13       75020  ILE-DE-FRANCE  Chef-lieu canton       197.1    PARIS
# 14       75010  ILE-DE-FRANCE  Chef-lieu canton        95.9    PARIS
# 15       75016  ILE-DE-FRANCE  Chef-lieu canton       169.4    PARIS
# 16       75018  ILE-DE-FRANCE  Chef-lieu canton       200.6    PARIS
# 17       75007  ILE-DE-FRANCE  Chef-lieu canton        57.4    PARIS
# 18       75015  ILE-DE-FRANCE  Chef-lieu canton       236.5    PARIS
# 19       75014  ILE-DE-FRANCE  Chef-lieu canton       137.2    PARIS
#
#     longitude   latitude
# 0    2.337460  48.876896
# 1    2.344107  48.867903
# 2    2.378741  48.859415
# 3    2.359361  48.863054
# 4    2.332671  48.848968
# 5    2.357362  48.854228
# 6    2.336293  48.862630
# 7    2.307486  48.887337
# 8    2.312583  48.872527
# 9    2.362468  48.828718
# 10   2.419807  48.835156
# 11   2.349859  48.844509
# 12   2.384694  48.886869
# 13   2.400820  48.863187
# 14   2.361113  48.876029
# 15   2.262100  48.860399
# 16   2.348712  48.892735
# 17   2.312439  48.856083
# 18   2.293559  48.840155
# 19   2.327101  48.828993

# %%
######################################Foursquare API###################################################

CLIENT_ID = 'BD4RPOVDJXG3XZVQOEZ21U3YPLDDN54A1N1B2VJN0YK2ZGXH' # your Foursquare ID
CLIENT_SECRET = 'AM1CVWE0WTR010OKUM0POZYHVE1KSA1YQ0FEZSXY4HSGPAWR' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
 # A default Foursquare API limit value

def getNearbyRestau(name,latitudes, longitudes,typ,radius=500):
    LIMIT=100
    lat=latitudes
    lng=longitudes
    #categoryId="4d4b7105d754a06374d81259"
    typ=typ

    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&query={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT,
            typ)

    results=requests.get(url).json()["response"]['groups'][0]['items']
    venues_list=[]
    venues_list.append([(
            name,
            lat,
            lng,
            v['venue']['location']['formattedAddress'],
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = [
                  'Neiborghood',
                  'Neigh lat',
                   'Neigh long',
                  'postalCode',
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    return(nearby_venues)

# %%
##############################dataset restau################################

df=[]
for i in range(len(neighborhood)):
       df.append(getNearbyRestau(neighborhood["postal_code"][i],neighborhood["latitude"][i], neighborhood["longitude"][i],"restaurant"))
        
Venues_arr=pd.concat(df)
Venues_arr.reset_index(inplace=True)
Venues_arr.drop(columns=["index"],inplace=True)

###############################Retrieve the neiberghood######################
def funcreplace(tab):
    try:
        if tab[2]=="France":
            return tab[1].split()[0].strip()
    except:
        try:
            if tab[1]=="France":
                return tab[0].split()[0].strip()
        except:
            if tab[0]=="France":
                return "N/A"

def funcarrdt(x):
    try:
        if int(x)>75000:
            return str(int(x)-75000)
        else:
            return "N/A"
    except:
        return "N/A"
Venues_arr["Arrdt"]=Venues_arr['postalCode'].apply(lambda row: funcreplace(row))

# %%
##########################Study on restaurant in Paris################################
Venues_arr.groupby(["Arrdt"]).agg(['count']).reset_index().droplevel(1, axis=1).sort_values(by=['Venue']) #Paris,210,58,94160,N/A
wordcloud = WordCloud().generate(" ".join(Venues_arr["Venue Category"]))
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 

plt.show()

# %%
################dataset marché##############################

df2=[]
for i in range(len(neighborhood)):
    try:
        df2.append(getNearbyRestau(neighborhood["postal_code"][i],neighborhood["latitude"][i], neighborhood["longitude"][i],"Farmers Market"))
    except ValueError:
        print("Error")
        
market_arr=pd.concat(df2)
market_arr.reset_index(inplace=True)
market_arr.drop(columns=["index"],inplace=True)

market_arr["Arrdt"]=market_arr['postalCode'].apply(lambda row: funcreplace(row))
market_arr["Arrdt"]=market_arr["Arrdt"].apply(lambda row:funcarrdt(row))
# Out:
# Error
# Error
# Error
# Error

# %%
##############################Tous les marchés ouverts alimentaires de paris##############################
url ="https://opendata.paris.fr/api/records/1.0/search/?dataset=marches-decouverts&q=&rows=10000&refine.produit=Alimentaire"
results=requests.get(url).json()["records"]
march=[]
march.append([(
            v["fields"]['produit'],
            v["fields"]['nom_long'], 
            v['fields']['ardt'],
            v['fields']['geo_point_2d'][0],
            v['fields']['geo_point_2d'][1]) for v in results])

nearby_market = pd.DataFrame([item for march in march for item in march])
nearby_market.columns = [
                  'product',
                  'Venue', 
                  'Neiberghood', 
                  'Latitude', 
                  'Longitude']
########################################market dataset########################################################
nearby_market=nearby_market[["Venue","Neiberghood","Latitude","Longitude"]]
nearby_market.columns=["Venue","Neiberghood","Venue Latitude","Venue Longitude"]
market_arr=market_arr[["Venue","Arrdt","Venue Latitude","Venue Longitude"]]
market_arr.columns=["Venue","Neiberghood","Venue Latitude","Venue Longitude"]
df=[market_arr,nearby_market]
market=pd.concat(df)
market["Neiberghood"]=market["Neiberghood"].apply(lambda row:str(row).strip())

# %%
###############################Study on market data#########################

Count_market=market.groupby(["Neiberghood"]).agg(['count']).reset_index().droplevel(1, axis=1)[["Neiberghood","Venue"]]
#reset index pour enelver multi index sur ligne et droplevel pour enlever le count sur les colonnes.
Count_market.sort_values(by=['Venue'])#number of markets per neiborghood
plt.bar(Count_market.sort_values(by=['Venue'])["Neiberghood"], Count_market.sort_values(by=['Venue'])["Venue"], width=0.5,tick_label=Count_market.sort_values(by=['Venue'])["Neiberghood"])
plt.hist(Count_market.sort_values(by=['Venue'])["Venue"],bins=100)
plt.xticks(Count_market.sort_values(by=['Venue'])["Neiberghood"])
plt.show()

# %%
#######################K-means method#############################

Venues_arr=Venues_arr[["Neiborghood","Neigh lat","Neigh long","Venue","Venue Latitude","Venue Longitude","Venue Category"]]

# %%
Venues_arr.groupby('Neiborghood').count()
# Out:
#              Neigh lat  Neigh long  Venue  Venue Latitude  Venue Longitude  \
# Neiborghood
# 75001               81          81     81              81               81
# 75002              100         100    100             100              100
# 75003               87          87     87              87               87
# 75004              100         100    100             100              100
# 75005               79          79     79              79               79
# 75006               31          31     31              31               31
# 75007               73          73     73              73               73
# 75008               39          39     39              39               39
# 75009              100         100    100             100              100
# 75010               99          99     99              99               99
# 75011               47          47     47              47               47
# 75012                5           5      5               5                5
# 75013               63          63     63              63               63
# 75014               25          25     25              25               25
# 75015               64          64     64              64               64
# 75016                1           1      1               1                1
# 75017               67          67     67              67               67
# 75018               52          52     52              52               52
# 75019               34          34     34              34               34
# 75020               50          50     50              50               50
#
#              Venue Category
# Neiborghood
# 75001                    81
# 75002                   100
# 75003                    87
# 75004                   100
# 75005                    79
# 75006                    31
# 75007                    73
# 75008                    39
# 75009                   100
# 75010                    99
# 75011                    47
# 75012                     5
# 75013                    63
# 75014                    25
# 75015                    64
# 75016                     1
# 75017                    67
# 75018                    52
# 75019                    34
# 75020                    50

# %%
# one hot encoding
venue_arr_onehot = pd.get_dummies(Venues_arr[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
venue_arr_onehot['Neiborghood'] = Venues_arr['Neiborghood'] 

# move neighborhood column to the first column
fixed_columns = [venue_arr_onehot.columns[-1]] + list(venue_arr_onehot.columns[:-1])
venue_arr_onehot = venue_arr_onehot[fixed_columns]

venue_arr_onehot.head()

venue_arr_grouped = venue_arr_onehot.groupby('Neiborghood').mean().reset_index()

# %%
from sklearn.cluster import KMeans
venue_arr_grouped

# set number of clusters
kclusters = 2

venue_arr_grouped_clustering = venue_arr_grouped#.drop('Neiborghood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(venue_arr_grouped_clustering)
venue_arr_grouped_clustering["Cluster"]=kmeans.labels_[:]

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:100] 
venue_arr_grouped_clustering=venue_arr_grouped_clustering.merge(neighborhood, left_on='Neiborghood', right_on='postal_code')

# %%
# create map
map_clusters = folium.Map(location=[48.8566, 2.3522], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(venue_arr_grouped_clustering['latitude'], venue_arr_grouped_clustering['longitude'], venue_arr_grouped_clustering['postal_code'], venue_arr_grouped_clustering['Cluster']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_b541caf10eda4b7caff13168ba6c506f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_b541caf10eda4b7caff13168ba6c506f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_b541caf10eda4b7caff13168ba6c506f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_b541caf10eda4b7caff13168ba6c506f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B48.8566%2C%202.3522%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# <img src="https://github.com/Elabriffe/Capstone-project/blob/main/Capture%20d%E2%80%99e%CC%81cran%202021-01-26%20a%CC%80%2020.35.06.png?raw=true"/>

# %% [markdown]
# ## Conclusion
#
# Cluster 1 is marked by purple circle markers. It is about borough where restauration market is not saturated and we can start here a restaurant business.
#
# Adding to that, we saw on our histogram, than most open market are in the 13th borough so it could be interisting to open a restaurant there. Adding to this, if we look at our first dataset, the 13th borough is one of the most populated in Paris.
#
# Finally with word cloud, we saw that most part of the restaurant in Paris are French restuarant so it could be interesting to open something else as an italian restaurant which are also present in Paris but not in the same quantity.
#
# Cluster 0 is marked by red markers. It is about neighborhoods where restauration market is saturated and it is not recommended here to start a restaurant business.
#
# ## Possible improvement
#
# We could take into account different other information. For exemple we could take into account the influence in Paris depending on hours. Adding to this, we could take also into account if there are some event organised in the neiberghood in question. Finally, we could check which neiberghood is the most connected to the different part in Paris.
